# %%
import os

# %%
os.chdir("/Users/spencervenancio/Downloads/Thesis")
# !pwd
# !ls
# Out:
# /Users/spencervenancio/Downloads/Thesis
# __init__.py data        lit         notebooks   plots       src

# %%
from src.utils import get_patches
from src.loco import loco

patches = get_patches(patch_size=4)          # 7x7 = 49 patches for 28x28
scores = loco(fitted_model, patches, X_train, X_test, y_train, y_test)

# For individual pixels:
scores = loco(fitted_model, [np.array([i]) for i in range(784)], ...)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.utils import get_patches
#       2 from src.loco import loco
#       4 patches = get_patches(patch_size=4)          # 7x7 = 49 patches for 28x28
#
# ModuleNotFoundError: No module named 'src.utils'
